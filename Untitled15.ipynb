# %% [markdown]
# <a href="https://colab.research.google.com/github/Sdimadim/All_Activities-Advanced_Pred/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Sdimadim/Activity_Feb22/main/PanelData.csv")

# %%
df.head()
# Out:
#    I  T        C         Q      PF        LF
# 0  1  1  1140640  0.952757  106650  0.534487
# 1  1  2  1215690  0.986757  110307  0.532328
# 2  1  3  1309570  1.091980  110574  0.547736
# 3  1  4  1511530  1.175780  121974  0.540846
# 4  1  5  1676730  1.160170  196606  0.591167

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   I       90 non-null     int64
#  1   T       90 non-null     int64
#  2   C       90 non-null     int64
#  3   Q       90 non-null     float64
#  4   PF      90 non-null     int64
#  5   LF      90 non-null     float64
# dtypes: float64(2), int64(4)
# memory usage: 4.3 KB

# %%
df['LF'] = pd.to_numeric(df['LF'],errors= 'coerce'). astype('int64')

# %%
df['LF'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 90 entries, 0 to 89
# Series name: LF
# Non-Null Count  Dtype
# --------------  -----
# 90 non-null     int64
# dtypes: int64(1)
# memory usage: 848.0 bytes

# %%
df.head()
# Out:
#    I  T        C         Q      PF  LF
# 0  1  1  1140640  0.952757  106650   0
# 1  1  2  1215690  0.986757  110307   0
# 2  1  3  1309570  1.091980  110574   0
# 3  1  4  1511530  1.175780  121974   0
# 4  1  5  1676730  1.160170  196606   0

# %%
print(df['LF'])
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 85    0
# 86    0
# 87    0
# 88    0
# 89    0
# Name: LF, Length: 90, dtype: int64

# %%
df['Q'] = pd.to_numeric(df['Q'], errors= 'coerce').astype('int64')

# %%
df['Q'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 90 entries, 0 to 89
# Series name: Q
# Non-Null Count  Dtype
# --------------  -----
# 90 non-null     int64
# dtypes: int64(1)
# memory usage: 848.0 bytes

# %%
df.head()
# Out:
#    I  T        C  Q      PF  LF  I_gap
# 0  1  1  1140640  0  106650   0     -1
# 1  1  2  1215690  0  110307   0     -1
# 2  1  3  1309570  1  110574   0     -1
# 3  1  4  1511530  1  121974   0     -1
# 4  1  5  1676730  1  196606   0     -1

# %%
df['I_gap'] =df['LF'] - df['I']

# %%
df['I_gap']
# Out:
# 0    -1
# 1    -1
# 2    -1
# 3    -1
# 4    -1
#      ..
# 85   -6
# 86   -6
# 87   -6
# 88   -6
# 89   -6
# Name: I_gap, Length: 90, dtype: int64
